# %%
from game import battle, SuperKnight, SuperArcher, hero, villain
from game import *
# Out:
# ...
# SuperArcher takes 150 damage
#
#
# SuperKnight: 3100 HP
# SuperArcher: 950 HP
# ...
# SuperArcher used his super ability!
# SuperKnight took 200 damage after armor reduction!
# SuperKnight took 200 damage after armor reduction!
# SuperKnight took 200 damage after armor reduction!
# SuperKnight took 200 damage after armor reduction!
# SuperKnight took 200 damage after armor reduction!
#
#
# SuperKnight: 2100 HP
# SuperArcher: 950 HP
# ...
# SuperKnight healed for 400 HP!
#
#
# SuperKnight: 2500 HP
# SuperArcher: 950 HP
# ...
# SuperArcher takes 150 damage
#
#
# SuperKnight: 2500 HP
# SuperArcher: 800 HP
# ...
# SuperArcher takes 150 damage
#
#
# SuperKnight: 2500 HP
# SuperArcher: 650 HP
# ...
# SuperKnight took 200 damage after armor reduction!
#
#
# SuperKnight: 2300 HP
# SuperArcher: 650 HP
# ...
# SuperArcher takes 150 damage
#
#
# SuperKnight: 2300 HP
# SuperArcher: 500 HP
# ...
# SuperArcher takes 150 damage
#
#
# SuperKnight: 2300 HP
# SuperArcher: 350 HP
# ...
# SuperKnight took 200 damage after armor reduction!
#
#
# ...

# %%
c1 = SuperKnight("SuperKnight", 3500, 150, 50)
c2 = SuperArcher("SuperArcher", 2000, 250, 0.1)

battle(c1, c2)
# Out:
# Battle begins!
# ...
# SuperArcher takes 150 damage
#
#
# SuperKnight: 3500 HP
# SuperArcher: 1850 HP
# ...
# SuperArcher takes 150 damage
#
#
# SuperKnight: 3500 HP
# SuperArcher: 1700 HP
# ...
# SuperArcher takes 150 damage
#
#
# SuperKnight: 3500 HP
# SuperArcher: 1550 HP
# ...
# SuperKnight took 200 damage after armor reduction!
#
#
# SuperKnight: 3300 HP
# SuperArcher: 1550 HP
# ...
# SuperArcher takes 150 damage
#
#
# SuperKnight: 3300 HP
# SuperArcher: 1400 HP
# ...
# SuperKnight took 200 damage after armor reduction!
#
#
# SuperKnight: 3100 HP
# SuperArcher: 1400 HP
# ...
# SuperKnight took 200 damage after armor reduction!
#
#
# SuperKnight: 2900 HP
# SuperArcher: 1400 HP
# ...
# SuperArcher takes 150 damage
#
#
# SuperKnight: 2900 HP
# SuperArcher: 1250 HP
# ...
# SuperKnight took 200 damage after armor reduction!
#
#
# SuperKnight: 2700 HP
# SuperArcher: 1250 HP
# ...
# SuperArcher used his super ability!
# SuperKnight took 200 damage after armor reduction!
# SuperKnight took 200 damage after armor reduction!
# ...
